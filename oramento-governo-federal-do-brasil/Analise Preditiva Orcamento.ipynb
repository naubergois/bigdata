# %%
import pandas as pd

# %%
orcamento=pd.read_csv('2019_OrcamentoDespesa.zip.csv', encoding = "ISO-8859-1",sep=";")

# %%
orcamento
# Out:
#        EXERCÍCIO  CÓDIGO ÓRGÃO SUPERIOR              NOME ÓRGÃO SUPERIOR  \
# 0           2019                   3000      Tribunal de Contas da União
# 1           2019                  20000         Presidência da República
# 2           2019                  20000         Presidência da República
# 3           2019                  20000         Presidência da República
# 4           2019                  20000         Presidência da República
# ...          ...                    ...                              ...
# 23651       2019                  81000  Ministério dos Direitos Humanos
# 23652       2019                  81000  Ministério dos Direitos Humanos
# 23653       2019                  81000  Ministério dos Direitos Humanos
# 23654       2019                  81000  Ministério dos Direitos Humanos
# 23655       2019                  81000  Ministério dos Direitos Humanos
#
#        CÓDIGO ÓRGÃO SUBORDINADO  \
# 0                          3000
# 1                         24208
# 2                         20101
# 3                         24208
# 4                         24208
# ...                         ...
# 23651                     81000
# 23652                     81000
# 23653                     30202
# 23654                     30202
# 23655                     81000
#
#                                   NOME ÓRGÃO SUBORDINADO  \
# 0      Tribunal de Contas da União - Unidades com vín...
# 1         Instituto Nacional de Tecnologia da Informação
# 2                               Presidência da República
# 3         Instituto Nacional de Tecnologia da Informação
# 4         Instituto Nacional de Tecnologia da Informação
# ...                                                  ...
# 23651  Ministério dos Direitos Humanos - Unidades com...
# 23652  Ministério dos Direitos Humanos - Unidades com...
# 23653                         Fundação Nacional do Índio
# 23654                         Fundação Nacional do Índio
# 23655  Ministério dos Direitos Humanos - Unidades com...
#
#        CÓDIGO UNIDADE ORÇAMENTÁRIA  \
# 0                             3101
# 1                            20204
# 2                            20101
# 3                            20204
# 4                            20204
# ...                            ...
# 23651                        81101
# 23652                        81101
# 23653                        81201
# 23654                        81201
# 23655                        81101
#
#                            NOME UNIDADE ORÇAMENTÁRIA  CÓDIGO FUNÇÃO  \
# 0      TRIBUNAL DE CONTAS DA UNIAO                                1
# 1      INST.NAC.DE TECNOLOGIA DA INFORMACAO-ITI                   4
# 2      PRESIDENCIA DA REPUBLICA                                   4
# 3      INST.NAC.DE TECNOLOGIA DA INFORMACAO-ITI                   4
# 4      INST.NAC.DE TECNOLOGIA DA INFORMACAO-ITI                   4
# ...                                              ...            ...
# 23651  MINISTERIO DOS DIREITOS HUMANOS - MDH                     14
# 23652  MINISTERIO DOS DIREITOS HUMANOS - MDH                     14
# 23653  FUNDACAO NACIONAL DO INDIO - FUNAI                        14
# 23654  FUNDACAO NACIONAL DO INDIO - FUNAI                        14
# 23655  MINISTERIO DOS DIREITOS HUMANOS - MDH                     14
#
#                  NOME FUNÇÃO  CÓDIGO SUBFUNÇÃO  ...  \
# 0                Legislativa                32  ...
# 1              Administração               125  ...
# 2              Administração               122  ...
# 3              Administração               125  ...
# 4              Administração               125  ...
# ...                      ...               ...  ...
# 23651  Direitos da cidadania               422  ...
# 23652  Direitos da cidadania               422  ...
# 23653  Direitos da cidadania               122  ...
# 23654  Direitos da cidadania               122  ...
# 23655  Direitos da cidadania               122  ...
#
#                                                NOME AÇÃO  \
# 0      FISCALIZACAO DA APLICACAO DOS RECURSOS PUBLICO...
# 1      GESTAO DO SISTEMA NACIONAL DE CERTIFICACAO DIG...
# 2              GESTAO DE POLITICAS PUBLICAS DE JUVENTUDE
# 3      GESTAO DO SISTEMA NACIONAL DE CERTIFICACAO DIG...
# 4      GESTAO DO SISTEMA NACIONAL DE CERTIFICACAO DIG...
# ...                                                  ...
# 23651                        DEFESA DOS DIREITOS HUMANOS
# 23652                        DEFESA DOS DIREITOS HUMANOS
# 23653                           ADMINISTRACAO DA UNIDADE
# 23654                           ADMINISTRACAO DA UNIDADE
# 23655                           ADMINISTRACAO DA UNIDADE
#
#        CÓDIGO CATEGORIA ECONÔMICA NOME CATEGORIA ECONÔMICA  \
# 0                               3       DESPESAS CORRENTES
# 1                               3       DESPESAS CORRENTES
# 2                               4      DESPESAS DE CAPITAL
# 3                               3       DESPESAS CORRENTES
# 4                               3       DESPESAS CORRENTES
# ...                           ...                      ...
# 23651                           3       DESPESAS CORRENTES
# 23652                           3       DESPESAS CORRENTES
# 23653                           3       DESPESAS CORRENTES
# 23654                           3       DESPESAS CORRENTES
# 23655                           3       DESPESAS CORRENTES
#
#       CÓDIGO GRUPO DE DESPESA      NOME GRUPO DE DESPESA  \
# 0                           3  Outras Despesas Correntes
# 1                           3  Outras Despesas Correntes
# 2                           4              Investimentos
# 3                           3  Outras Despesas Correntes
# 4                           3  Outras Despesas Correntes
# ...                       ...                        ...
# 23651                       3  Outras Despesas Correntes
# 23652                       3  Outras Despesas Correntes
# 23653                       3  Outras Despesas Correntes
# 23654                       3  Outras Despesas Correntes
# 23655                       3  Outras Despesas Correntes
#
#        CÓDIGO ELEMENTO DE DESPESA  \
# 0                              39
# 1                              40
# 2                               0
# 3                              35
# 4                              39
# ...                           ...
# 23651                           0
# 23652                          36
# 23653                          92
# 23654                          33
# 23655                          33
#
#                                 NOME ELEMENTO DE DESPESA  \
# 0         Outros Serviços de Terceiros - Pessoa Jurídica
# 1      Serviços de Tecnologia da Informação e Comunic...
# 2                                          Não informado
# 3                                Serviços de Consultoria
# 4         Outros Serviços de Terceiros - Pessoa Jurídica
# ...                                                  ...
# 23651                                      Não informado
# 23652       Outros Serviços de Terceiros - Pessoa Física
# 23653                  Despesas de Exercícios Anteriores
# 23654                 Passagens e Despesas com Locomoção
# 23655                 Passagens e Despesas com Locomoção
#
#        ORÇAMENTO INICIAL (R$) ORÇAMENTO ATUALIZADO (R$)  \
# 0                         ,00                       ,00
# 1                   460200,00                 460200,00
# 2                    95000,00                       ,00
# 3                    72000,00                  72000,00
# 4                  1102500,00                1102500,00
# ...                       ...                       ...
# 23651             20205253,32               20205253,32
# 23652                20000,00                  20000,00
# 23653               440341,41                 440341,41
# 23654               238710,20                 238710,20
# 23655               947218,57                 947218,57
#
#        ORÇAMENTO REALIZADO (R$)
# 0                      23218,26
# 1                      31092,75
# 2                           ,00
# 3                           ,00
# 4                     255373,71
# ...                         ...
# 23651                       ,00
# 23652                       ,00
# 23653                       ,00
# 23654                       ,00
# 23655                  10118,47
#
# [23656 rows x 24 columns]

# %%
tribunal_contas=orcamento[orcamento["CÓDIGO ÓRGÃO SUPERIOR"]==3000]

# %%
tribunal_contas
# Out:
#    EXERCÍCIO  CÓDIGO ÓRGÃO SUPERIOR          NOME ÓRGÃO SUPERIOR  \
# 0       2019                   3000  Tribunal de Contas da União
#
#    CÓDIGO ÓRGÃO SUBORDINADO  \
# 0                      3000
#
#                               NOME ÓRGÃO SUBORDINADO  \
# 0  Tribunal de Contas da União - Unidades com vín...
#
#    CÓDIGO UNIDADE ORÇAMENTÁRIA                      NOME UNIDADE ORÇAMENTÁRIA  \
# 0                         3101  TRIBUNAL DE CONTAS DA UNIAO
#
#    CÓDIGO FUNÇÃO  NOME FUNÇÃO  CÓDIGO SUBFUNÇÃO  ...  \
# 0              1  Legislativa                32  ...
#
#                                            NOME AÇÃO  \
# 0  FISCALIZACAO DA APLICACAO DOS RECURSOS PUBLICO...
#
#    CÓDIGO CATEGORIA ECONÔMICA NOME CATEGORIA ECONÔMICA  \
# 0                           3       DESPESAS CORRENTES
#
#   CÓDIGO GRUPO DE DESPESA      NOME GRUPO DE DESPESA  \
# 0                       3  Outras Despesas Correntes
#
#    CÓDIGO ELEMENTO DE DESPESA                        NOME ELEMENTO DE DESPESA  \
# 0                          39  Outros Serviços de Terceiros - Pessoa Jurídica
#
#    ORÇAMENTO INICIAL (R$) ORÇAMENTO ATUALIZADO (R$)  ORÇAMENTO REALIZADO (R$)
# 0                     ,00                       ,00                  23218,26
#
# [1 rows x 24 columns]
