# %%
#!pip install convertdate
#!pip install fbprophet
import pandas as pd
import glob
from fbprophet import Prophet


path = r'/home/naubergois/git/bigdata/compras' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0, encoding = "ISO-8859-1",sep=";")
    li.append(df)

compras = pd.concat(li, axis=0, ignore_index=True)

# %%
compras.head(5)
# Out:
#    CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 0                  63000  ADVOCACIA-GERAL DA UNIAO         63000
# 1                  63000  ADVOCACIA-GERAL DA UNIAO         63000
# 2                  63000  ADVOCACIA-GERAL DA UNIAO         63000
# 3                  63000  ADVOCACIA-GERAL DA UNIAO         63000
# 4                  63000  ADVOCACIA-GERAL DA UNIAO         63000
#
#                                           NOME ÓRGÃO  CÓDIGO UNIDADE GESTORA  \
# 0  ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...                  110581
# 1  ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...                  110581
# 2  ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...                  110581
# 3  ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...                  110581
# 4  ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...                  110581
#
#                     NOME UNIDADE GESTORA  ANO EXTRATO  MÊS EXTRATO  \
# 0  DIVISAO DE DIARIAS E PASSAGENS DA AGU         2016           11
# 1  DIVISAO DE DIARIAS E PASSAGENS DA AGU         2016           11
# 2  DIVISAO DE DIARIAS E PASSAGENS DA AGU         2016           11
# 3  DIVISAO DE DIARIAS E PASSAGENS DA AGU         2016           11
# 4  DIVISAO DE DIARIAS E PASSAGENS DA AGU         2016           11
#
#                 TIPO AQUISIÇÃO  CNPJ OU CPF FAVORECIDO  \
# 0  Aquisição de Passagem Aérea           9296295000160
# 1  Aquisição de Passagem Aérea           9296295000160
# 2  Aquisição de Passagem Aérea           9296295000160
# 3  Aquisição de Passagem Aérea           9296295000160
# 4  Aquisição de Passagem Aérea           9296295000160
#
#                        NOME FAVORECIDO                TRANSAÇÃO  \
# 0  AZUL LINHAS AEREAS BRASILEIRAS S.A.  COMPRA A/V - R$ - APRES
# 1  AZUL LINHAS AEREAS BRASILEIRAS S.A.  COMPRA A/V - R$ - APRES
# 2  AZUL LINHAS AEREAS BRASILEIRAS S.A.  COMPRA A/V - R$ - APRES
# 3  AZUL LINHAS AEREAS BRASILEIRAS S.A.  COMPRA A/V - R$ - APRES
# 4  AZUL LINHAS AEREAS BRASILEIRAS S.A.  COMPRA A/V - R$ - APRES
#
#   DATA TRANSAÇÃO VALOR TRANSAÇÃO
# 0     14/10/2016          770,50
# 1     18/10/2016          602,69
# 2     20/10/2016          473,92
# 3     30/09/2016          384,54
# 4     24/10/2016          434,88

# %%
agu=compras[compras['CÓDIGO ÓRGÃO SUPERIOR']==63000]
agu=agu.filter(['ANO EXTRATO','MÊS EXTRATO','VALOR TRANSAÇÃO'])
agu['VALOR TRANSAÇÃO']=agu['VALOR TRANSAÇÃO'].str.replace(',','.')
agu['VALOR TRANSAÇÃO']=agu['VALOR TRANSAÇÃO'].astype(float)

# %%
agu.head(10)
# Out:
#    ANO EXTRATO  MÊS EXTRATO  VALOR TRANSAÇÃO
# 0         2016           11           770.50
# 1         2016           11           602.69
# 2         2016           11           473.92
# 3         2016           11           384.54
# 4         2016           11           434.88
# 5         2016           11           544.70
# 6         2016           11           133.31
# 7         2016           11           602.69
# 8         2016           11           675.44
# 9         2016           11           440.91

# %%
compras_mes_ano=agu.groupby(['ANO EXTRATO','MÊS EXTRATO']).sum()
#compras_mes_ano=agu

# %%
compras_mes_ano=compras_mes_ano.reset_index()

# %%
compras_mes_ano["ds"] = compras_mes_ano["ANO EXTRATO"].astype(str) +'-'+ compras_mes_ano["MÊS EXTRATO"].astype(str)

# %%
compras_mes_ano["y"]=compras_mes_ano['VALOR TRANSAÇÃO']

# %%
ultimos_meses=compras_mes_ano[-3:]

# %%
ultimos_meses
# Out:
#     ANO EXTRATO  MÊS EXTRATO  VALOR TRANSAÇÃO      ds          y
# 38         2018            6        160915.06  2018-6  160915.06
# 39         2018            7        154485.95  2018-7  154485.95
# 40         2018            8         19626.56  2018-8   19626.56

# %%
compras_mes_ano=compras_mes_ano[:-3]

# %%
m = Prophet(seasonality_mode='multiplicative')
m.fit(compras_mes_ano)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# Python
future = m.make_future_dataframe(periods=3, freq='M')

fcst = m.predict(future)
fig = m.plot_components(fcst)

# %%
fcst[-3:]
# Out:
#              ds       trend  yhat_lower   yhat_upper  trend_lower  \
# 9653 2019-05-31  683.879066  239.633103  1192.263879   666.935880
# 9654 2019-06-30  687.025886  108.769449  1057.635196   667.216653
# 9655 2019-07-31  690.277600   40.119729  1017.292566   667.588332
#
#       trend_upper  multiplicative_terms  multiplicative_terms_lower  \
# 9653   700.379805              0.052345                    0.052345
# 9654   705.780893             -0.161859                   -0.161859
# 9655   711.642629             -0.261277                   -0.261277
#
#       multiplicative_terms_upper    yearly  yearly_lower  yearly_upper  \
# 9653                    0.052345  0.052345      0.052345      0.052345
# 9654                   -0.161859 -0.161859     -0.161859     -0.161859
# 9655                   -0.261277 -0.261277     -0.261277     -0.261277
#
#       additive_terms  additive_terms_lower  additive_terms_upper        yhat
# 9653             0.0                   0.0                   0.0  719.676932
# 9654             0.0                   0.0                   0.0  575.824339
# 9655             0.0                   0.0                   0.0  509.923820

# %%
ultimos_meses
# Out:
#     ANO EXTRATO  MÊS EXTRATO  VALOR TRANSAÇÃO      ds          y
# 38         2018            6        160915.06  2018-6  160915.06
# 39         2018            7        154485.95  2018-7  154485.95
# 40         2018            8         19626.56  2018-8   19626.56

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the sequence
		if end_ix > len(sequence)-1:
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

# %%
from numpy import array
 
n_steps = 3

X, y = split_sequence(compras_mes_ano['y'], n_steps)

# %%
# !pip install keras
# !pip install tensorflow
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense

model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# Out:
# Requirement already satisfied: keras in /home/naubergois/miniconda3/envs/bioinformatics/lib/python3.6/site-packages (2.3.1)
# Requirement already satisfied: h5py in /home/naubergois/miniconda3/envs/bioinformatics/lib/python3.6/site-packages (from keras) (2.10.0)
# Requirement already satisfied: pyyaml in /home/naubergois/miniconda3/envs/bioinformatics/lib/python3.6/site-packages (from keras) (5.3)
# Requirement already satisfied: keras-applications>=1.0.6 in /home/naubergois/miniconda3/envs/bioinformatics/lib/python3.6/site-packages (from keras) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /home/naubergois/miniconda3/envs/bioinformatics/lib/python3.6/site-packages (from keras) (1.18.1)
# Requirement already satisfied: scipy>=0.14 in /home/naubergois/miniconda3/envs/bioinformatics/lib/python3.6/site-packages (from keras) (1.4.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /home/naubergois/miniconda3/envs/bioinformatics/lib/python3.6/site-packages (from keras) (1.1.0)
# Requirement already satisfied: six>=1.9.0 in /home/naubergois/miniconda3/envs/bioinformatics/lib/python3.6/site-packages (from keras) (1.14.0)
# Collecting tensorflow
#   Downloading tensorflow-2.1.0-cp36-cp36m-manylinux2010_x86_64.whl (421.8 MB)
#      |████████▌                       | 112.0 MB 17.3 MB/s eta 0:00:18
